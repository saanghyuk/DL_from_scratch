# %% [markdown]
# # Chapter.7.04 Activation function
#
# PA 7.04에서는 PA 7.03에서 구현했던 Sigmoid 함수와 더불어<br>
# Tanh함수와 ReLU함수를 구현할 것입니다

# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib.cm as cm

import os
import sys
np.random.seed(0)

# %% [markdown]
# ***
# ## tanh Function
#
# 먼저 tanh function은 다음과 같은 식으로 표현된다.
# <center>
# $tanh(x) = \frac{\exp^{z} - \exp^{-z}}{\exp^{z} + \exp^{-z}}$
# </center>
# 이 tanh function을 numpy를 이용해 구현해보자.

# %%
x_range = np.linspace(-10, 10, 1000)
# Start tanhFunction
y = (np.exp(x_range) - np.exp(-x_range))/(np.exp(x_range) + np.exp(-x_range))
# End tanh Function 

fig, ax = plt.subplots(figsize = (12, 5))
ax.plot(x_range, y)
#ax.grid()

# %% [markdown]
# **Expected Output**
# <img src='./img_7/7_04_1.png' width = 700>

# %% [markdown]
# ***
# ## ReLU Function
#
# 먼저 ReLU은 다음과 같은 식으로 표현된다.
# <center>
# $0 , wherez < 0$<br>
# $1 , wherez >= 0$
# </center>
# 즉 다음과 같이 표현할 수 있다<br>
# <center>$max(0,z)$<br></center>
# 이 ReLU function을 numpy를 이용해 구현해보자.

# %%
x_range = np.linspace(-10, 10, 1000)
# Start ReLU Function
y = [0 if x <=0 else x for x in x_range]
# End ReLU Function 

fig, ax = plt.subplots(figsize = (12, 5))
ax.plot(x_range, y)
#ax.grid()

# %% [markdown]
# **Expected Output**
# <img src='./img_7/7_04_02.png' width = 700>
